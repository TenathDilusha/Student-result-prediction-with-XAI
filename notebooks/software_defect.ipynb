# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../dataset/software_defect_prediction_dataset.csv')
df.head()
# Out:
#    lines_of_code  cyclomatic_complexity  num_functions  num_classes  \
# 0            910                     12              7           79
# 1           3822                      9            197           72
# 2           3142                     20             99           92
# 3            516                     39             52           79
# 4           4476                     27            162           75
#
#    comment_density  code_churn  developer_experience_years  num_developers  \
# 0             0.59         539                          19               4
# 1             0.30         584                           8               8
# 2             0.11         593                           0               6
# 3             0.18          81                          12              14
# 4             0.21         918                          14               1
#
#    commit_frequency  bug_fix_commits  past_defects  test_coverage  \
# ...

# %%
df.describe()
# Out:
#        lines_of_code  cyclomatic_complexity  num_functions   num_classes  \
# count   60000.000000           60000.000000   60000.000000  60000.000000
# mean     2530.351467              25.085650      99.900683     49.371517
# std      1428.229382              14.112331      57.367154     28.827881
# min        50.000000               1.000000       1.000000      0.000000
# 25%      1299.000000              13.000000      50.000000     24.000000
# 50%      2534.000000              25.000000      99.000000     49.000000
# 75%      3763.000000              37.000000     149.000000     74.000000
# max      4999.000000              49.000000     199.000000     99.000000
#
#        comment_density    code_churn  developer_experience_years  \
# count     60000.000000  60000.000000                60000.000000
# mean          0.300259    500.247800                    9.465667
# std           0.173254    288.724453                    5.768672
# ...

# %%
df.columns
# Out:
# Index(['lines_of_code', 'cyclomatic_complexity', 'num_functions',
#        'num_classes', 'comment_density', 'code_churn',
#        'developer_experience_years', 'num_developers', 'commit_frequency',
#        'bug_fix_commits', 'past_defects', 'test_coverage',
#        'duplication_percentage', 'avg_function_length', 'depth_of_inheritance',
#        'response_for_class', 'coupling_between_objects', 'lack_of_cohesion',
#        'build_failures', 'static_analysis_warnings',
#        'security_vulnerabilities', 'performance_issues', 'defect'],
#       dtype='str')
